# %%
#We are installing required libraries first

# !pip install datasets pandas matplotlib seaborn
# Out:
# ...
#      ---------------------------------------- 0.0/57.7 kB ? eta -:--:--
#      ----------------------------------- ---- 51.2/57.7 kB 1.3 MB/s eta 0:00:01
#      ---------------------------------------- 57.7/57.7 kB 1.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/491.2 kB ? eta -:--:--
#    ----- ---------------------------------- 61.4/491.2 kB ? eta -:--:--
#    ---------- ----------------------------- 122.9/491.2 kB 1.4 MB/s eta 0:00:01
#    --------------------- ------------------ 266.2/491.2 kB 2.0 MB/s eta 0:00:01
#    ------------------------- -------------- 317.4/491.2 kB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 491.2/491.2 kB 2.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/469.0 kB ? eta -:--:--
#    -------------------- ------------------- 235.5/469.0 kB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  460.8/469.0 kB 5.7 MB/s eta 0:00:01
# ...

# %%
# Load & Explore ATIS Dataset (Using HuggingFace Datasets)


from datasets import load_dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load ATIS dataset from HuggingFace
atis = load_dataset("atis")

# Convert train dataset to pandas DataFrame
train_data = atis['train'].to_pandas()
test_data = atis['test'].to_pandas()

# Display dataset shape
print("Train Shape:", train_data.shape)
print("Test Shape:", test_data.shape)

# Preview first few rows
print(train_data.head())
# Out:
# ---------------------------------------------------------------------------
# DatasetNotFoundError                      Traceback (most recent call last)
# Cell In[4], line 10
#       7 import seaborn as sns
#       9 # Load ATIS dataset from HuggingFace
# ---> 10 atis = load_dataset("atis")
#      12 # Convert train dataset to pandas DataFrame
#      13 train_data = atis['train'].to_pandas()
#
# File ~\anaconda3\Lib\site-packages\datasets\load.py:2062, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2057 verification_mode = VerificationMode(
#    2058     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2059 )
#    2061 # Create a dataset builder
# -> 2062 builder_instance = load_dataset_builder(
#    2063     path=path,
# ...
